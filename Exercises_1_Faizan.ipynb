# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#sales = pd.read_csv(
#    'data/sales_data.csv',
#    parse_dates=['Date'])

url0 = 'https://github.com/FaizanKhalidMohsin/FreeCodeCamp-Pandas-Real-Life-Example/blob/master/data/sales_data.csv'
# you need the link to the 'raw' file on github to read the data.
url = 'https://raw.githubusercontent.com/FaizanKhalidMohsin/FreeCodeCamp-Pandas-Real-Life-Example/master/data/sales_data.csv'
sales = pd.read_csv(url
                    ,parse_dates=['Date'])



sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
print(sales['Customer_Age'].mean())
print(sales.Customer_Age.mean())
# Out:
# 35.91921157861212
# 35.91921157861212

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
for kind in ['kde', 'density', 'box']: 
        sales.Customer_Age.plot(kind = kind, figsize=(14,6))
        plt.show()

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales.Order_Quantity.mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
for kind in ['hist', 'kde', 'box']:
    
    if(kind != 'box'):
        sales.Order_Quantity.plot(kind=kind, figsize=(14,6))
        plt.show()
    else:
        sales.Order_Quantity.plot(kind=kind, figsize=(14,6), vert = False)
        plt.show()

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
print(sales.Year.value_counts())
print(sales.Year.count())
print(sales.shape)
# Out:
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64
# 113036
# (113036, 18)

# %%
sales['Year'].value_counts()
# Out:
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales.Year.value_counts().plot(kind="pie", figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Year'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales.Month.value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
sales['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales.Month.value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
print(sales.columns)
print(sales.Country.value_counts().head(0))
print(sales.Country.value_counts().head(1))
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')
# Series([], Name: Country, dtype: int64)
# United States    39206
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts().head(1)
# Out:
# United States    39206
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales.Country.value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
print(sales.columns)
print(sales.Product.unique())
# print(unique(sales.Product)) # Unlike R, python does not have function unique() in base, but pd has method unique()
print(sales.Product.unique().itemsize)
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')
# ['Hitch Rack - 4-Bike' 'All-Purpose Bike Stand' 'Mountain Bottle Cage'
#  'Water Bottle - 30 oz.' 'Road Bottle Cage' 'AWC Logo Cap'
#  'Bike Wash - Dissolver' 'Fender Set - Mountain' 'Half-Finger Gloves, L'
#  'Half-Finger Gloves, M' 'Half-Finger Gloves, S' 'Sport-100 Helmet, Black'
#  'Sport-100 Helmet, Red' 'Sport-100 Helmet, Blue'
#  'Hydration Pack - 70 oz.' 'Short-Sleeve Classic Jersey, XL'
#  'Short-Sleeve Classic Jersey, L' 'Short-Sleeve Classic Jersey, M'
#  'Short-Sleeve Classic Jersey, S' 'Long-Sleeve Logo Jersey, M'
#  'Long-Sleeve Logo Jersey, XL' 'Long-Sleeve Logo Jersey, L'
#  'Long-Sleeve Logo Jersey, S' 'Mountain-100 Silver, 38'
#  'Mountain-100 Silver, 44' 'Mountain-100 Black, 48'
# ...

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales.Product.value_counts().plot(kind='bar', figsize = (14,6))
plt.show()
sales.Product.value_counts().head(10).plot(kind='bar', figsize = (14,6))
plt.show()

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize = (14,6))
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
variable_pair_list = [ ['Unit_Cost', 'Unit_Price'], ['Order_Quantity','Profit'], ['Country','Profit']]

for variable_pair in variable_pair_list:
    print(variable_pair)
    print(variable_pair[0]);print(variable_pair[1])
    sales.plot(kind='scatter', x=variable_pair[0], y=variable_pair[1], figsize=(14,6))
    plt.show()
 
sales.plot(kind='box', x='Country', y='Profit')
plt.show()
#sales['Country', 'Profit'].plot(kind='box') # THis does not work outright
#plt.show()
# Out:
# ['Unit_Cost', 'Unit_Price']
# Unit_Cost
# Unit_Price
# ['Order_Quantity', 'Profit']
# Order_Quantity
# Profit
# ['Country', 'Profit']
# Country
# Profit

# %%
#print(['Profit', 'Country'])
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(14,6))
plt.show()

var_par_list = [['Profit', 'Country'], ['Customer_Age', 'Country']]
for var_par in var_par_list:
    print(var_par)
    sales[[var_par[0], var_par[1]]].boxplot(by = var_par[1], figsize=(14,6))
    plt.show()
# Out:
# ['Profit', 'Country']
# ['Customer_Age', 'Country']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(14,6))
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
print(sales.columns)
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here

sales.plot(kind = 'line', x = 'Calculated_Date', y = 'Order_Quantity')
#sales[['Calculated_Date', 'Order_Quantity']].line(x = 'Calculated_Date', y = 'Order_Quantity')
sales.Calculated_Date.value_counts().plot(kind= 'line', figsize=(14,6))
plt.show()

sales.plot(kind = 'line', x = 'Calculated_Date', y = 'Order_Quantity', figsize=(14,6))
plt.show()
sales.Calculated_Date.value_counts().plot(kind= 'line', figsize=(14,6))
plt.show()

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
print(sales.columns)
sales['Revenue'] = sales['Revenue'] + 50
sales['Revenue'] += 50
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
#print(sales.Country == 'Canada' or 'France')
#sales.Country[sales.Country == 'Canada' or 'France']
# sales.Country in ['Canada', 'France']
#sales.query('Country == Canada')
#sales.query('Country.str.startswith("Canada", "France").values')
#sales.query('Country.str.startswith("Canada" | "France").values')
#sales.query('Country.str.contains("Canada")')
#sales.query('Country.str.contains(["Canada", "France"])')
print(sum(sales.Country.str.contains("Canada")))
print(sum(sales.Country.str.contains("Canada|France")))
# Out:
# 14178
# 25176

# %%
#print(sales.columns)
#print(sales.Product.unique)
#print(sales.Product_Category.unique)

print(sum(sales.Product.str.contains('Bike Racks')))
print(sum(sales.Product_Category.str.contains('Bike Racks')))
# Out:
# 0
# 0

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
print(sum(sales[sales.Country.str.contains('Canada')].Product.str.contains('Rack|rack')))
print(sum(sales[sales.Country.str.contains('Canada')].Sub_Category.str.contains('Bike Rack')))
print(sales[sales.Country.str.contains('Canada') & sales.Sub_Category.str.contains('Bike Rack')].shape)
print(sales[sales.Country.str.contains('Canada') & sales.Sub_Category.str.contains('Bike Rack')].shape[0])

# print(sales[sales.Country.str.contains('Canada') & sales.Sub_Category.str.contains('Bike Rack')].shape(0))
# The shape method does not have round brackets like the value_counts(). It does not have any inherent brackets in the method.
# To take elements of it you need to slice it hence use square brackets []
# Out:
# 104
# 104
# (104, 19)
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
print(sales.columns)
print(sales[sales.Country.str.contains('France')].State.value_counts())
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales.columns
prod_cat = sales.Product_Category.value_counts()
prod_cat.plot(kind = 'bar', figsize = (14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Product_Category'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
prod_cat.plot(kind='pie', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Product_Category'>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Product_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
sales.columns
sub_cat = sales.Sub_Category.value_counts()
print(sub_cat)

for kind in ['bar', 'pie']:
    sub_cat.plot(kind=kind, figsize=(14,6))
    plt.show()
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Road Bikes           13430
# Helmets              12158
# Mountain Bikes        8854
# Jerseys               6010
# Caps                  4358
# Fenders               4032
# Touring Bikes         3698
# Gloves                2686
# Cleaners              1802
# Shorts                1794
# Hydration Packs       1334
# Socks                 1122
# Vests                  964
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
for kind in ['bar', 'pie']:
    accessories.plot(kind= kind, figsize=(14,6))
    plt.show()

# %%
accessories.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
#sales.Product.str.contains('Bike')

sales.loc[sales.Product_Category.contains('Bike')].Sub_Category.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-799523c9a2b4> in <module>
#       2 #sales.Product.str.contains('Bike')
#       3
# ----> 4 sales[sales.Product_Category.contains('Bike')].Sub_Category.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'contains'

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

# %%
bikes.plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here

# %%
sales['Customer_Gender'].value_counts()

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
